# %% [markdown]
# Dobbiamo generare prima la classe madre
#
# • Classe Animale:
# ◦ Attributi:
# ▪ stringa: nome
# ▪ intero: età
# ◦ Metodi:
# ▪ info (che non fa niente)
# ▪ parla (che non fa niente)
# ▪ muove (che non fa niente)
# ▪ mangia (che non fa niente)
# ▪ beve (che non fa niente)
# ▪ dorme (che accetta un intero n e si ferma per n secondi)
# ▪ get/set per nome ed età

# %%
import random as rnd

# %%
class Animale:
    def __init__(self, nome : str, eta : int):
        self.nome = nome
        self.eta = eta

    def Info():
        pass
    
    def parla():
        pass    
    def muove ():
        pass
    def mangia():   
        pass
    def beve ():
        pass
    def dorme (n:int):   
        time.sleep(n)
        return f"{self.nome} ha dormito per {n} secondi"

class Elefante(Animale):
    def __init__(self, nome : str, eta : int, suono : str):
        super().__init__(nome, eta)
        self.suono = suono
    def Info(self):
            return f"Leone: {self.nome}, Età: {self.eta}, Ruggito: {self.ruggito}"
        
    def parla(self):
        return f"{self.nome} dice: {self.ruggito}"
    
    def muove(self):
        movimenti = ["corre", "salta", "cammina lentamente"]
        return f"{self.nome} {rnd.choice(movimenti)}"
    
    def mangia(self):
        cibi = ["carne", "pollo", "pesce"]
        return f"{self.nome} mangia {rnd.choice(cibi)}"
    
    def beve(self):
        bevande = ["acqua", "latte"]
        return f"{self.nome} beve {rnd.choice(bevande)}"

# %% [markdown]
# Classe Leone

# %%
class Leone(Animale):
    def __init__(self, nome : str, eta : int, ruggito : str):
        super().__init__(nome, eta)
        self.ruggito = ruggito

    def Info(self):
        return f"Leone: {self.nome}, Età: {self.eta}, Ruggito: {self.ruggito}"
    
    def parla(self):
        return f"{self.nome} dice: {self.ruggito}"
    
    def muove(self):
        movimenti = ["corre", "salta", "cammina lentamente"]
        return f"{self.nome} {rnd.choice(movimenti)}"
    
    def mangia(self):
        cibi = ["carne", "pollo", "pesce"]
        return f"{self.nome} mangia {rnd.choice(cibi)}"
    
    def beve(self):
        bevande = ["acqua", "latte"]
        return f"{self.nome} beve {rnd.choice(bevande)}"
